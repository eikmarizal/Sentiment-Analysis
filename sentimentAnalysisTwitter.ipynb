# %%
from IPython.display import Image
Image(filename='octocat.PNG')

# %%
import pandas as pd
#Import pandas

# %%
# !pip install tweepy

# %%
import tweepy
#Import tweepy

# %%
# !pip install vaderSentiment

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

key = tweepy.API(auth)

tweets = key.search('Data Science', count=100)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 1  Introduction to Data Science in Python: Dive i...
# 2  RT @DanRather: U.S. presidents sit at an apex ...
# 3  RT @siliconrepublic: Whoever said that arts de...
# 4  RT @wiresmith: Have been writing a chapter-len...
# 5  RT @MobileHarv: Old Weather, a citizen-science...
# 6  RT @Biz_Retail: The weekly #Retail newsletter ...
# 7  RT @Earth_Challenge: Citizen science + tech in...
# 8  The government is back open.\nHow much science...
# 9  RT @turinginst: Deadline to apply for this yea...
# 2019-01-28 17:20:04

# %%
import nltk
#nltk.downloader.download('vader_lexicon')

# %%
sia = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  sps = sia.polarity_scores(row["Tweets"])
  listy.append(sps)
  
sel = pd.Series(listy)
data['polarity'] = sel.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 1   Introduction to Data Science in Python: Dive i...
# 2   RT @DanRather: U.S. presidents sit at an apex ...
# 3   RT @siliconrepublic: Whoever said that arts de...
# 4   RT @wiresmith: Have been writing a chapter-len...
# 5   RT @MobileHarv: Old Weather, a citizen-science...
# 6   RT @Biz_Retail: The weekly #Retail newsletter ...
# 7   RT @Earth_Challenge: Citizen science + tech in...
# 8   The government is back open.\nHow much science...
# 9   RT @turinginst: Deadline to apply for this yea...
# 10  RT @ANACoins: Using the internet, I began to s...
# 11  RT @MOXOFF_MathXInn: #datascience al servizio ...
# 12  RT @24infodata: La data science è automatizzat...
# 13  Just published!\n►►►►►►►►► \n@Gartner_Inc Magi...
# 14  6th grade Earth Science spent class analyzing ...
# 15  New post (principal engineer - ST, marketing t...
# 16  Data Science Engineer II: Data Science Enginee...
# 17  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 18  RT @kinggary: Join us at 3pm today for Quantit...
# 19  @Michael_F_Page @yes_that_dolly @CEB1980 @Cael...
# 20  Don't miss the data at #WorkHuman! A feel-good...
# 21  RT @UCSJacob: Out with a new report today, and...
# 22  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 23  The data and sources in this thread have me RO...
# 24  RT @ShashiTharoor: On #DataPrivacyDay2019, goo...
# 25  Text Mining with R: A Tidy Approach https://t....
# 26  RT @UCSJacob: Out with a new report today, and...
# 27  @ppopians @Ish_Bhandari Hey please note that T...
# 28  RT @Docorange1: Functional, impulse-based quan...
# 29  On behalf of TAG's Data Science &amp; Analytic...
# ..                                                ...
# 70  RT @DanRather: U.S. presidents sit at an apex ...
# 71  RT @YwanVanLoon: RT Ronald_vanLoon "#DataScien...
# 72  RT @askdrstats: Three principles of data scien...
# 73  RT @DanRather: U.S. presidents sit at an apex ...
# 74  RT Ronald_vanLoon "#DataScience Workflow: Over...
# 75  RT @AMCELL: Early Career Researchers Embrace D...
# 76  RT @MColebrook: Finally, our latest chapter is...
# 77  @wisermann @RoKhanna Yeah, no. There is no sci...
# 78  Shopee Singapore National Data Science Challen...
# 79  RT @AmFamJack: Threat of earthquakes, floods &...
# 80  Science data chats with our wonderful team. @M...
# 81  Data Science and social equity! Can't wait to ...
# 82  @michaelhoffman @bvoight28 @sciencemagazine @d...
# 83  RT @DanRather: U.S. presidents sit at an apex ...
# 84  #1 The Intelligence Factory #MakeSmart Intelli...
# 85  @CoachRoach93 @chadfelixg No I don't.\n\nIn de...
# 86  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 87  Three principles of data science: predictabili...
# 88  RT @chubicki: Storytelling is pivotal in scien...
# 89  Royal Dutch @Shell Spreads Data Science Succes...
# 90  New investments by the @RockefellerFdn and @Ma...
# 91  RT @sapinker: The political systems of many co...
# 92            @StefanMolyneux https://t.co/nkRvrsDKwD
# 93  #DataScience Workflow: Overview and Challenges...
# 94  RT @plantae_org: Early Career Researchers Embr...
# 95  RT @moorejh: How #bigdata has created a big cr...
# 96  @RealDeanCain Yeah, my kid did a project about...
# 97  RT @DataScienceCtrl: 47 New External Data Scie...
# 98  RT @Speleo_Steve: Collecting data off of speci...
# 99  RT @stubutchart: Are long-line fishing vessels...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'comp...
# 2   {'neg': 0.134, 'neu': 0.788, 'pos': 0.079, 'co...
# 3   {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'comp...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'comp...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'comp...
# 8   {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'comp...
# 9   {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'comp...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'comp...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...
# 21  {'neg': 0.076, 'neu': 0.924, 'pos': 0.0, 'comp...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.077, 'neu': 0.765, 'pos': 0.158, 'co...
# 24  {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'comp...
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26  {'neg': 0.076, 'neu': 0.924, 'pos': 0.0, 'comp...
# 27  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 28  {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'comp...
# 29  {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'comp...
# ..                                                ...
# 70  {'neg': 0.134, 'neu': 0.788, 'pos': 0.079, 'co...
# 71  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 73  {'neg': 0.134, 'neu': 0.788, 'pos': 0.079, 'co...
# 74  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'comp...
# 75  {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'comp...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.297, 'neu': 0.618, 'pos': 0.085, 'co...
# 78  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...
# 79  {'neg': 0.139, 'neu': 0.861, 'pos': 0.0, 'comp...
# 80  {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'comp...
# 81  {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'comp...
# 82  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 83  {'neg': 0.134, 'neu': 0.788, 'pos': 0.079, 'co...
# 84  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'comp...
# 85  {'neg': 0.105, 'neu': 0.762, 'pos': 0.133, 'co...
# 86  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 88  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'comp...
# 89  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'comp...
# 90  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...
# 91  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'comp...
# 94  {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'comp...
# 95  {'neg': 0.255, 'neu': 0.621, 'pos': 0.124, 'co...
# 96  {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'comp...
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 98  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'comp...
# 99  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [100 rows x 2 columns]
